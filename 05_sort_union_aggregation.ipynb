# %%
#create spark session
from pyspark.sql import SparkSession
spark = (SparkSession
         .builder
         .appName("Working with sort, union, aggregation")
         .master("local[*]")
         .getOrCreate()
        )

# %%
spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://7dabc22fc68a:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.3.0</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>Working with sort, union, aggregation</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
# Emp Data & Schema

emp_data_1 = [
    ["001","101","John Doe","30","Male","50000","2015-01-01"],
    ["002","101","Jane Smith","25","Female","45000","2016-02-15"],
    ["003","102","Bob Brown","35","Male","55000","2014-05-01"],
    ["004","102","Alice Lee","28","Female","48000","2017-09-30"],
    ["005","103","Jack Chan","40","Male","60000","2013-04-01"],
    ["006","103","Jill Wong","32","Female","52000","2018-07-01"],
    ["007","101","James Johnson","42","Male","70000","2012-03-15"],
    ["008","102","Kate Kim","29","Female","51000","2019-10-01"],
    ["009","103","Tom Tan","33","Male","58000","2016-06-01"],
    ["010","104","Lisa Lee","27","Female","47000","2018-08-01"]
]

emp_data_2 = [
    ["011","104","David Park","38","Male","65000","2015-11-01"],
    ["012","105","Susan Chen","31","Female","54000","2017-02-15"],
    ["013","106","Brian Kim","45","Male","75000","2011-07-01"],
    ["014","107","Emily Lee","26","Female","46000","2019-01-01"],
    ["015","106","Michael Lee","37","Male","63000","2014-09-30"],
    ["016","107","Kelly Zhang","30","Female","49000","2018-04-01"],
    ["017","105","George Wang","34","Male","57000","2016-03-15"],
    ["018","104","Nancy Liu","29","","50000","2017-06-01"],
    ["019","103","Steven Chen","36","Male","62000","2015-08-01"],
    ["020","102","Grace Kim","32","Female","53000","2018-11-01"]
]

emp_schema = "employee_id string, department_id string, name string, age string, gender string, salary string, hire_date string"

# %%
#create dataframe
emp_data_1 = spark.createDataFrame(data=emp_data_1, schema=emp_schema)
emp_data_2 = spark.createDataFrame(data=emp_data_2, schema=emp_schema)

# %%
emp_data_1.printSchema()
emp_data_2.printSchema()
# Out:
# root
#  |-- employee_id: string (nullable = true)
#  |-- department_id: string (nullable = true)
#  |-- name: string (nullable = true)
#  |-- age: string (nullable = true)
#  |-- gender: string (nullable = true)
#  |-- salary: string (nullable = true)
#  |-- hire_date: string (nullable = true)
#
# root
#  |-- employee_id: string (nullable = true)
#  |-- department_id: string (nullable = true)
#  |-- name: string (nullable = true)
#  |-- age: string (nullable = true)
#  |-- gender: string (nullable = true)
#  |-- salary: string (nullable = true)
#  |-- hire_date: string (nullable = true)

# %%
emp_data_1.show()
emp_data_2.show()
# Out:
# +-----------+-------------+-------------+---+------+------+----------+
# |employee_id|department_id|         name|age|gender|salary| hire_date|
# +-----------+-------------+-------------+---+------+------+----------+
# |        001|          101|     John Doe| 30|  Male| 50000|2015-01-01|
# |        002|          101|   Jane Smith| 25|Female| 45000|2016-02-15|
# |        003|          102|    Bob Brown| 35|  Male| 55000|2014-05-01|
# |        004|          102|    Alice Lee| 28|Female| 48000|2017-09-30|
# |        005|          103|    Jack Chan| 40|  Male| 60000|2013-04-01|
# |        006|          103|    Jill Wong| 32|Female| 52000|2018-07-01|
# |        007|          101|James Johnson| 42|  Male| 70000|2012-03-15|
# |        008|          102|     Kate Kim| 29|Female| 51000|2019-10-01|
# |        009|          103|      Tom Tan| 33|  Male| 58000|2016-06-01|
# |        010|          104|     Lisa Lee| 27|Female| 47000|2018-08-01|
# +-----------+-------------+-------------+---+------+------+----------+
#
# +-----------+-------------+-----------+---+------+------+----------+
# |employee_id|department_id|       name|age|gender|salary| hire_date|
# +-----------+-------------+-----------+---+------+------+----------+
# |        011|          104| David Park| 38|  Male| 65000|2015-11-01|
# |        012|          105| Susan Chen| 31|Female| 54000|2017-02-15|
# |        013|          106|  Brian Kim| 45|  Male| 75000|2011-07-01|
# |        014|          107|  Emily Lee| 26|Female| 46000|2019-01-01|
# |        015|          106|Michael Lee| 37|  Male| 63000|2014-09-30|
# |        016|          107|Kelly Zhang| 30|Female| 49000|2018-04-01|
# |        017|          105|George Wang| 34|  Male| 57000|2016-03-15|
# |        018|          104|  Nancy Liu| 29|      | 50000|2017-06-01|
# |        019|          103|Steven Chen| 36|  Male| 62000|2015-08-01|
# |        020|          102|  Grace Kim| 32|Female| 53000|2018-11-01|
# +-----------+-------------+-----------+---+------+------+----------+

# %%
#union & union all
emp = emp_data_1.unionAll(emp_data_2)

# %%
emp.show()
# Out:
# +-----------+-------------+-------------+---+------+------+----------+
# |employee_id|department_id|         name|age|gender|salary| hire_date|
# +-----------+-------------+-------------+---+------+------+----------+
# |        001|          101|     John Doe| 30|  Male| 50000|2015-01-01|
# |        002|          101|   Jane Smith| 25|Female| 45000|2016-02-15|
# |        003|          102|    Bob Brown| 35|  Male| 55000|2014-05-01|
# |        004|          102|    Alice Lee| 28|Female| 48000|2017-09-30|
# |        005|          103|    Jack Chan| 40|  Male| 60000|2013-04-01|
# |        006|          103|    Jill Wong| 32|Female| 52000|2018-07-01|
# |        007|          101|James Johnson| 42|  Male| 70000|2012-03-15|
# |        008|          102|     Kate Kim| 29|Female| 51000|2019-10-01|
# |        009|          103|      Tom Tan| 33|  Male| 58000|2016-06-01|
# |        010|          104|     Lisa Lee| 27|Female| 47000|2018-08-01|
# |        011|          104|   David Park| 38|  Male| 65000|2015-11-01|
# |        012|          105|   Susan Chen| 31|Female| 54000|2017-02-15|
# |        013|          106|    Brian Kim| 45|  Male| 75000|2011-07-01|
# |        014|          107|    Emily Lee| 26|Female| 46000|2019-01-01|
# |        015|          106|  Michael Lee| 37|  Male| 63000|2014-09-30|
# |        016|          107|  Kelly Zhang| 30|Female| 49000|2018-04-01|
# |        017|          105|  George Wang| 34|  Male| 57000|2016-03-15|
# |        018|          104|    Nancy Liu| 29|      | 50000|2017-06-01|
# |        019|          103|  Steven Chen| 36|  Male| 62000|2015-08-01|
# |        020|          102|    Grace Kim| 32|Female| 53000|2018-11-01|
# +-----------+-------------+-------------+---+------+------+----------+

# %%
from pyspark.sql.functions import desc, asc, col
emp_sorted = emp.orderBy(col("salary").desc())

# %%
emp_sorted.show()
# Out:
# +-----------+-------------+-------------+---+------+------+----------+
# |employee_id|department_id|         name|age|gender|salary| hire_date|
# +-----------+-------------+-------------+---+------+------+----------+
# |        013|          106|    Brian Kim| 45|  Male| 75000|2011-07-01|
# |        007|          101|James Johnson| 42|  Male| 70000|2012-03-15|
# |        011|          104|   David Park| 38|  Male| 65000|2015-11-01|
# |        015|          106|  Michael Lee| 37|  Male| 63000|2014-09-30|
# |        019|          103|  Steven Chen| 36|  Male| 62000|2015-08-01|
# |        005|          103|    Jack Chan| 40|  Male| 60000|2013-04-01|
# |        009|          103|      Tom Tan| 33|  Male| 58000|2016-06-01|
# |        017|          105|  George Wang| 34|  Male| 57000|2016-03-15|
# |        003|          102|    Bob Brown| 35|  Male| 55000|2014-05-01|
# |        012|          105|   Susan Chen| 31|Female| 54000|2017-02-15|
# |        020|          102|    Grace Kim| 32|Female| 53000|2018-11-01|
# |        006|          103|    Jill Wong| 32|Female| 52000|2018-07-01|
# |        008|          102|     Kate Kim| 29|Female| 51000|2019-10-01|
# |        001|          101|     John Doe| 30|  Male| 50000|2015-01-01|
# |        018|          104|    Nancy Liu| 29|      | 50000|2017-06-01|
# |        016|          107|  Kelly Zhang| 30|Female| 49000|2018-04-01|
# |        004|          102|    Alice Lee| 28|Female| 48000|2017-09-30|
# |        010|          104|     Lisa Lee| 27|Female| 47000|2018-08-01|
# |        014|          107|    Emily Lee| 26|Female| 46000|2019-01-01|
# |        002|          101|   Jane Smith| 25|Female| 45000|2016-02-15|
# +-----------+-------------+-------------+---+------+------+----------+

# %%
from pyspark.sql.functions import desc, asc, col
emp_sorted = emp.orderBy(col("department_id").desc())

# %%
emp_sorted.show()
# Out:
# +-----------+-------------+-------------+---+------+------+----------+
# |employee_id|department_id|         name|age|gender|salary| hire_date|
# +-----------+-------------+-------------+---+------+------+----------+
# |        014|          107|    Emily Lee| 26|Female| 46000|2019-01-01|
# |        016|          107|  Kelly Zhang| 30|Female| 49000|2018-04-01|
# |        013|          106|    Brian Kim| 45|  Male| 75000|2011-07-01|
# |        015|          106|  Michael Lee| 37|  Male| 63000|2014-09-30|
# |        012|          105|   Susan Chen| 31|Female| 54000|2017-02-15|
# |        017|          105|  George Wang| 34|  Male| 57000|2016-03-15|
# |        011|          104|   David Park| 38|  Male| 65000|2015-11-01|
# |        010|          104|     Lisa Lee| 27|Female| 47000|2018-08-01|
# |        018|          104|    Nancy Liu| 29|      | 50000|2017-06-01|
# |        006|          103|    Jill Wong| 32|Female| 52000|2018-07-01|
# |        005|          103|    Jack Chan| 40|  Male| 60000|2013-04-01|
# |        009|          103|      Tom Tan| 33|  Male| 58000|2016-06-01|
# |        019|          103|  Steven Chen| 36|  Male| 62000|2015-08-01|
# |        003|          102|    Bob Brown| 35|  Male| 55000|2014-05-01|
# |        004|          102|    Alice Lee| 28|Female| 48000|2017-09-30|
# |        008|          102|     Kate Kim| 29|Female| 51000|2019-10-01|
# |        020|          102|    Grace Kim| 32|Female| 53000|2018-11-01|
# |        001|          101|     John Doe| 30|  Male| 50000|2015-01-01|
# |        007|          101|James Johnson| 42|  Male| 70000|2012-03-15|
# |        002|          101|   Jane Smith| 25|Female| 45000|2016-02-15|
# +-----------+-------------+-------------+---+------+------+----------+

# %%
#aggregation
from pyspark.sql.functions import count
emp_count = emp_sorted.groupBy("gender").agg(count("name").alias("number of members"))

# %%
emp_count.show()
# Out:
# +------+-----------------+
# |gender|number of members|
# +------+-----------------+
# |  Male|               10|
# |Female|                9|
# |      |                1|
# +------+-----------------+

# %%
#aggregation
from pyspark.sql.functions import sum
emp_sum = emp_sorted.groupBy("department_id").agg(sum("salary").alias("Total dept salary"))

# %%
emp_sum.show()
# Out:
# +-------------+-----------------+
# |department_id|Total dept salary|
# +-------------+-----------------+
# |          107|          95000.0|
# |          106|         138000.0|
# |          105|         111000.0|
# |          104|         162000.0|
# |          103|         232000.0|
# |          102|         207000.0|
# |          101|         165000.0|
# +-------------+-----------------+

# %%
#aggregating with having clause
from pyspark.sql.functions import avg
emp_avg = emp_sorted.groupBy("department_id").agg(avg("salary").alias("avg_dept_salary")).where("avg_dept_salary>50000")

# %%
emp_avg.show()
# Out:
# +-------------+---------------+
# |department_id|avg_dept_salary|
# +-------------+---------------+
# |          106|        69000.0|
# |          105|        55500.0|
# |          104|        54000.0|
# |          103|        58000.0|
# |          102|        51750.0|
# |          101|        55000.0|
# +-------------+---------------+

# %%
#unionbyName
emp_data_2_other = emp_data_2.select("employee_id", "salary", "department_id", "name", "hire_date", "gender", "age")

emp_data_1.printSchema()
emp_data_2_other.printSchema()
# Out:
# root
#  |-- employee_id: string (nullable = true)
#  |-- department_id: string (nullable = true)
#  |-- name: string (nullable = true)
#  |-- age: string (nullable = true)
#  |-- gender: string (nullable = true)
#  |-- salary: string (nullable = true)
#  |-- hire_date: string (nullable = true)
#
# root
#  |-- employee_id: string (nullable = true)
#  |-- salary: string (nullable = true)
#  |-- department_id: string (nullable = true)
#  |-- name: string (nullable = true)
#  |-- hire_date: string (nullable = true)
#  |-- gender: string (nullable = true)
#  |-- age: string (nullable = true)

# %%
emp_fixed = emp_data_1.unionByName(emp_data_2_other)

# %%
emp_fixed.show()
# Out:
# +-----------+-------------+-------------+---+------+------+----------+
# |employee_id|department_id|         name|age|gender|salary| hire_date|
# +-----------+-------------+-------------+---+------+------+----------+
# |        001|          101|     John Doe| 30|  Male| 50000|2015-01-01|
# |        002|          101|   Jane Smith| 25|Female| 45000|2016-02-15|
# |        003|          102|    Bob Brown| 35|  Male| 55000|2014-05-01|
# |        004|          102|    Alice Lee| 28|Female| 48000|2017-09-30|
# |        005|          103|    Jack Chan| 40|  Male| 60000|2013-04-01|
# |        006|          103|    Jill Wong| 32|Female| 52000|2018-07-01|
# |        007|          101|James Johnson| 42|  Male| 70000|2012-03-15|
# |        008|          102|     Kate Kim| 29|Female| 51000|2019-10-01|
# |        009|          103|      Tom Tan| 33|  Male| 58000|2016-06-01|
# |        010|          104|     Lisa Lee| 27|Female| 47000|2018-08-01|
# |        011|          104|   David Park| 38|  Male| 65000|2015-11-01|
# |        012|          105|   Susan Chen| 31|Female| 54000|2017-02-15|
# |        013|          106|    Brian Kim| 45|  Male| 75000|2011-07-01|
# |        014|          107|    Emily Lee| 26|Female| 46000|2019-01-01|
# |        015|          106|  Michael Lee| 37|  Male| 63000|2014-09-30|
# |        016|          107|  Kelly Zhang| 30|Female| 49000|2018-04-01|
# |        017|          105|  George Wang| 34|  Male| 57000|2016-03-15|
# |        018|          104|    Nancy Liu| 29|      | 50000|2017-06-01|
# |        019|          103|  Steven Chen| 36|  Male| 62000|2015-08-01|
# |        020|          102|    Grace Kim| 32|Female| 53000|2018-11-01|
# +-----------+-------------+-------------+---+------+------+----------+

# %%
emp.count()
# Out:
# 20
